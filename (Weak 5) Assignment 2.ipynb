# %%
'''
Q1: Explain why we have to use the Exception class while creating a Custom Exception.
Answer:
In Python, the Exception class serves as the base class for all exceptions. When creating a custom exception, 
it is recommended to inherit from the Exception class to maintain compatibility with the built-in exception hierarchy. 
This ensures that your custom exception behaves like a standard exception and allows for consistent handling in try-except
blocks. By inheriting from Exception, your custom exception can benefit from the general exception handling mechanisms 
provided by the language.
'''
# Out:
# '\nQ1: Explain why we have to use the Exception class while creating a Custom Exception.\nAnswer:\nIn Python, the Exception class serves as the base class for all exceptions. When creating a custom exception, \nit is recommended to inherit from the Exception class to maintain compatibility with the built-in exception hierarchy. \nThis ensures that your custom exception behaves like a standard exception and allows for consistent handling in try-except\nblocks. By inheriting from Exception, your custom exception can benefit from the general exception handling mechanisms \nprovided by the language.\n'

# %%
'''Q2: Write a Python program to print Python Exception Hierarchy.'''

# Program :

def print_exception_hierarchy(exception_class, indent=0):
    print("  " * indent + str(exception_class))
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 1)

print_exception_hierarchy(BaseException)
# Out:
# <class 'BaseException'>
#   <class 'Exception'>
#     <class 'TypeError'>
#       <class 'decimal.FloatOperation'>
#       <class 'email.errors.MultipartConversionError'>
#     <class 'StopAsyncIteration'>
#     <class 'StopIteration'>
#     <class 'ImportError'>
#       <class 'ModuleNotFoundError'>
#       <class 'zipimport.ZipImportError'>
#     <class 'OSError'>
#       <class 'ConnectionError'>
#         <class 'BrokenPipeError'>
#         <class 'ConnectionAbortedError'>
#         <class 'ConnectionRefusedError'>
#         <class 'ConnectionResetError'>
#           <class 'http.client.RemoteDisconnected'>
#       <class 'BlockingIOError'>
#       <class 'ChildProcessError'>
#       <class 'FileExistsError'>
#       <class 'FileNotFoundError'>
#       <class 'IsADirectoryError'>
#       <class 'NotADirectoryError'>
#       <class 'InterruptedError'>
#         <class 'zmq.error.InterruptedSystemCall'>
#       <class 'PermissionError'>
#       <class 'ProcessLookupError'>
# ...

# %%
'''
Q3: What errors are defined in the ArithmeticError class? Explain any two with an example.
Ans:
The ArithmeticError class is a base class for errors that occur during arithmetic operations. Two common errors under 
ArithmeticError are
'''
# ZeroDivisionError - Raised when division or modulo by zero is encountered.
try:
    result = 10 / 0  # This will raise a ZeroDivisionError
except ZeroDivisionError as e:
    print(f"Caught an exception: {e}")
    
#OverflowError - Raised when the result of an arithmetic operation is too large to be represented
import sys

try:
    result = sys.maxsize * 2  # This will raise an OverflowError on most systems
except OverflowError as e:
    print(f"Caught an exception: {e}")
# Out:
# Caught an exception: division by zero

# %%
'''
Q4: Why LookupError class is used? Explain with an example KeyError and IndexError.
Answer:
The LookupError class is a base class for errors that occur when a key or index used to access a mapping or sequence 
is invalid. Two common errors under LookupError are:
'''

#KeyError - Raised when a dictionary key is not found.
my_dict = {'a': 1, 'b': 2}
try:
    value = my_dict['c']  # This will raise a KeyError
except KeyError as e:
    print(f"Caught an exception: {e}")

#IndexError - Raised when trying to access an index that is out of range.
my_list = [1, 2, 3]
try:
    value = my_list[5]  # This will raise an IndexError
except IndexError as e:
    print(f"Caught an exception: {e}")
# Out:
# Caught an exception: 'c'
# Caught an exception: list index out of range

# %%
'''
Q5: Explain ImportError. What is ModuleNotFoundError?
Answer:
ImportError is a base class for exceptions related to importing modules. ModuleNotFoundError is a subclass of ImportError 
that specifically indicates that a module cannot be found.
'''

# Program :

try:
    import non_existing_module  # This will raise a ModuleNotFoundError
except ModuleNotFoundError as e:
    print(f"Caught an exception: {e}")
# Out:
# Caught an exception: No module named 'non_existing_module'

# %%
'''
Q6: List down some best practices for exception handling in Python.
Answer:

1. Use Specific Exceptions: Catch specific exceptions rather than using a broad except clause. It helps in understanding and 
handling specific issues.

2. Avoid Bare except: Avoid using a bare except clause as it catches all exceptions and may hide bugs. Be specific about 
the exceptions you want to catch.

3. Use finally for Cleanup: Use finally for cleanup code that should be executed regardless of whether an exception 
occurred or not.

4. Keep Try Blocks Small: Keep the code inside try blocks minimal to focus on the specific code that might raise an 
exception.

5. Handle Exceptions Locally: Handle exceptions as close to the source as possible. Avoid catching exceptions too broadly.

6. Log Exceptions: Use logging to record exceptions, including the traceback. It helps in debugging and analyzing issues.

7. Avoid Silent Failures: Avoid catching exceptions without taking any action. Silent failures make it challenging to 
identify and fix problems.

8. Custom Exception Messages: Provide informative and meaningful error messages when raising or catching exceptions. 
It aids in understanding the cause of the issue.

9. Use with for Resource Management: When dealing with resources like files or network connections, use with statements 
to ensure proper cleanup even in the presence of exceptions.

10. Test Exception Handling: Include testing scenarios that involve exceptions to ensure your exception handling mechanisms
work as expected.

'''
# Out:
# '\nQ6: List down some best practices for exception handling in Python.\nAnswer:\n\n1. Use Specific Exceptions: Catch specific exceptions rather than using a broad except clause. It helps in understanding and \nhandling specific issues.\n\n2. Avoid Bare except: Avoid using a bare except clause as it catches all exceptions and may hide bugs. Be specific about \nthe exceptions you want to catch.\n\n3. Use finally for Cleanup: Use finally for cleanup code that should be executed regardless of whether an exception \noccurred or not.\n\n4. Keep Try Blocks Small: Keep the code inside try blocks minimal to focus on the specific code that might raise an \nexception.\n\n5. Handle Exceptions Locally: Handle exceptions as close to the source as possible. Avoid catching exceptions too broadly.\n\n6. Log Exceptions: Use logging to record exceptions, including the traceback. It helps in debugging and analyzing issues.\n\n7. Avoid Silent Failures: Avoid catching exceptions without taking any action.
# ...
